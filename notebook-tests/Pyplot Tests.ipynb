# %% [markdown]
# ### Line plots

# %%
from matplotlib import pyplot as plt

# %%
data_x = [i for i in range(25, 36)]
data_y = [15, 27, 29, 35, 38, 44, 55, 58, 63, 68, 73]

py_data_x = [i for i in range(25, 36)]
py_data_y = [23, 34, 36, 45, 49, 56, 63, 68, 75, 80, 84]

java_data_x = [i for i in range(25, 36)]
java_data_y = [17, 30, 33, 38, 42, 48, 51, 57, 65, 72, 77]

# %%
plt.plot(data_x, data_y, label='Average Worker')
plt.plot(py_data_x, py_data_y, label='Python')
plt.plot(java_data_x, java_data_y, label='Java')
plt.xlabel('Age')
plt.ylabel('Median Salary (USD)')
plt.title('Median Salary (USD) per Age')
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# ## Bar plots
#
# Usually used for categorical data. Note that some numeric data can be converted into categories such as the age data below.

# %%
plt.bar(data_x, data_y, label='Average Worker')
# plt.plot(py_data_x, py_data_y, label='Python')
# plt.plot(java_data_x, java_data_y, label='Java')
plt.xlabel('Age')
plt.ylabel('Median Salary (USD)')
plt.title('Median Salary (USD) per Age')
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()

# %%
plt.bar(data_x, data_y, label='Average Worker')
plt.bar(py_data_x, py_data_y, label='Python')
plt.bar(java_data_x, java_data_y, label='Java')
plt.xlabel('Age')
plt.ylabel('Median Salary (USD)')
plt.title('Median Salary (USD) per Age')
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# > A graph has been overwritten and the layout doesn't look good.

# %%
import numpy as np
x_indices = np.arange(len(data_x))
width = 0.25

plt.bar(x_indices+width, data_y, width=width, label='Average Worker')
plt.bar(x_indices, py_data_y, width=width, label='Python')
plt.bar(x_indices-width, java_data_y, width=width, label='Java')

plt.xlabel('Age')
plt.ylabel('Median Salary (USD)')
plt.title('Median Salary (USD) per Age')
plt.legend()

plt.xticks(ticks=x_indices, labels=data_x)

plt.tight_layout()
plt.grid()
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/test_data_for_plotting.csv')
df.head()
# Out:
#    Responder_id                          LanguagesWorkedWith
# 0             1              HTML/CSS;Java;JavaScript;Python
# 1             2                          C++;HTML/CSS;Python
# 2             3                                     HTML/CSS
# 3             4                          C;C++;C#;Python;SQL
# 4             5  C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA

# %%
df.shape
# Out:
# (87569, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87569 entries, 0 to 87568
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Responder_id         87569 non-null  int64
#  1   LanguagesWorkedWith  87569 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 1.3+ MB

# %%
from collections import Counter
c = Counter()

# %%
langs = df['LanguagesWorkedWith']

for x in langs:
    c.update(x.split(';'))
c
# Out:
# Counter({'HTML/CSS': 55466,
#          'Java': 35917,
#          'JavaScript': 59219,
#          'Python': 36443,
#          'C++': 20524,
#          'C': 18017,
#          'C#': 27097,
#          'SQL': 47544,
#          'VBA': 4781,
#          'R': 5048,
#          'Bash/Shell/PowerShell': 31991,
#          'Ruby': 7331,
#          'Rust': 2794,
#          'TypeScript': 18523,
#          'WebAssembly': 1015,
#          'Other(s):': 7920,
#          'Go': 7201,
#          'PHP': 23030,
#          'Assembly': 5833,
#          'Kotlin': 5620,
#          'Swift': 5744,
#          'Objective-C': 4191,
#          'Elixir': 1260,
#          'Erlang': 777,
#          'Clojure': 1254,
#          'F#': 973,
#          'Scala': 3309,
#          'Dart': 1683})

# %%
languages = []
scores = []
for x in c.most_common(15):
    languages.append(x[0])
    scores.append(x[1])
languages.reverse()
scores.reverse()
plt.barh(languages, scores)
plt.show()

# %% [markdown]
# ## Pie charts

# %%
slices = [60, 40]
labels = ['Sixty', 'Forty']

plt.pie(slices, labels=labels, wedgeprops={'edgecolor': 'black'})
plt.show()

# %% [markdown]
# > Try explode and other params.

# %%
slices = [120, 80, 30, 20]
labels = ['Sixty', 'Forty', 'Extra1', 'Extra2']
colors = ['blue', 'red', 'green', 'yellow']
explode = [0, 0, 0, 0.1]

plt.pie(slices, labels=labels, wedgeprops={'edgecolor': 'black'}, colors=colors, explode=explode,
        shadow=True, startangle=90, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## Stack plots/Area plots

# %%
import numpy as np
minutes = np.arange(start=1, stop=10)
player1 = [0, 1, 1, 2, 4, 5, 5, 6, 8]
player2 = [0, 1, 2, 2, 2, 4, 4, 4, 4]
player3 = [0, 1, 1, 1, 2, 2, 3, 3, 4]
labels=['player1', 'player2', 'player3']

# %%
plt.stackplot(minutes, player1, player2, player3, labels=labels)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# > Note: Stack plots shows a series representation of a bar graph

# %% [markdown]
# ## Adding Fills

# %%
import pandas as pd
df = pd.read_csv('./data/test_data_for_plotting_2.csv')
df.head()
# Out:
#    Age  All_Devs  Python  JavaScript
# 0   18     17784   20046       16446
# 1   19     16500   17100       16791
# 2   20     18012   20000       18942
# 3   21     20628   24744       21780
# 4   22     25206   30500       25704

# %%
plt.plot(df['Age'], df['All_Devs'], color='#444444', linestyle='--', label='All Devs')
plt.plot(df['Age'], df['Python'], label='Python')

plt.fill_between(df['Age'], df['Python'], df['All_Devs'],
                 where=(df['Python']> df['All_Devs']), interpolate=True, alpha=0.25,
                label='Above Avg')
plt.fill_between(df['Age'], df['Python'], df['All_Devs'],
                 where=(df['Python']<= df['All_Devs']), interpolate=True, alpha=0.25,
                label='Below Avg')
# plt.fill_between(df['Age'], df['All_Devs'], alpha=0.25)

plt.title('Median Salary (USD) per Age')
plt.xlabel('Age')
plt.ylabel('Median Salary (USD)')
plt.legend()
plt.show()

# %% [markdown]
# ## Histograms
#
# Histograms can be compared to bar graphs but the main difference between the two is that histograms are used to graph the frequency/count for numerical data.

# %%
df = pd.read_csv('./data/test_data_for_plotting_3.csv')
df.head()
# Out:
#    Responder_id  Age
# 0             1   14
# 1             2   19
# 2             3   28
# 3             4   22
# 4             5   30

# %%
df.shape
# Out:
# (79210, 2)

# %%
ids = df['Responder_id']
ages = df['Age']

# %%
bins = [i for i in range(10, 110, 10)] # you can exclude data by removing them from the range in the bin

plt.hist(ages, bins=bins, edgecolor='black', log=True)
plt.axvline(29, color='#444444', label='Age Median')

plt.legend()
plt.xlabel('Age')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Scatter plots
#
# Scatter plots are used for bivariate analysis between two numeric features.

# %%
df = pd.read_csv('./data/test_data_for_plotting_4.csv')
df.head()
# Out:
#    view_count   likes  ratio
# 0     8036001  324742  96.91
# 1     9378067  562589  98.19
# 2     2182066  273650  99.38
# 3     6525864   94698  96.25
# 4     9481284  582481  97.22

# %%
plt.scatter(df['view_count'], df['likes'], s=100, c=df['ratio'],
            cmap='summer', edgecolor='black', linewidth=1, alpha=0.75)

cbar = plt.colorbar()
cbar.set_label('Like/Dislike Ratio')

plt.xscale('log')
plt.yscale('log')
plt.xlabel('View count')
plt.ylabel('Likes')
plt.show()

# %% [markdown]
# > Notes: s parameter -> sets the size of each marker
#
# >         c parameter -> sets the color of each marker/you can also pass a list of numbers or colors to emphasize each marker
#
# >         edgecolor parameter -> highlights bars/markers
