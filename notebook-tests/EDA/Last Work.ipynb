# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_excel('Applicant Confirmation Form AY 2023-2024 (Responses).xlsx')
df.head()
# Out:
#                 Timestamp        Email Address  \
# 0 2023-10-28 21:18:57.310  cogaviola@up.edu.ph
# 1 2023-10-28 21:20:10.797  jlcarpio3@up.edu.ph
# 2 2023-10-28 21:20:51.299    japeria@up.edu.ph
# 3 2023-10-28 21:21:38.340  kategrado@up.edu.ph
# 4 2023-10-28 21:22:00.875  aplpablo1@gmail.com
#
#   I give my consent to the UP Data Science Society to process my responses provided herewith in pursuant to the Philippine Data Privacy Act of 2012 and applicable laws.  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   I give my consent to the UP Data Science Society to process my responses provided herewith in pursuant to the Philippine Data Privacy Act of 2012 and applicable laws..1  \
# 0                                         2019-12099
# 1                                         2020-00209
# 2                                         2018-05911
# 3                                         2021-09799
# 4                                         2011-62590
#
#   last_name      first_name middle_name    nickname           personal_email  \
# 0   gaviola  crisarl sydney        orit         syd    arargaviola@gmail.com
# 1    carpio      jacqueline       lopez        jacq  itsjacqcarpio@gmail.com
# 2     peria            jano      alzate         jap      periajano@gmail.com
# 3   tegrado    kenneth renz       arceo        renz     kentegrado@gmail.com
# 4     pablo     adrian paul     llaguno  pabs / ian      aplpablo1@gmail.com
#
#                up_mail  ...  \
# 0  cogaviola@up.edu.ph  ...
# 1  jlcarpio3@up.edu.ph  ...
# 2    japeria@up.edu.ph  ...
# 3  kategrado@up.edu.ph  ...
# 4    alpablo@up.edu.ph  ...
#
#   preferred_committee_according_to_priority_[branding_&_creatives]  \
# 0                                    Lowest Priority
# 1                                    Lowest Priority
# 2                                      High Priority
# 3                                      High Priority
# 4                                      High Priority
#
#    preferred_committee_according_to_priority_[education_&_research]  \
# 0                                       Mid Priority
# 1                                       Low Priority
# 2                                 Very High Priority
# 3                                 Very High Priority
# 4                                 Very High Priority
#
#   preferred_committee_according_to_priority_[external_&_finance]  \
# 0                                 Very High Priority
# 1                                      High Priority
# 2                                       Mid Priority
# 3                                       Mid Priority
# 4                                       Mid Priority
#
#   preferred_committee_according_to_priority_[logistics]  \
# 0                                      High Priority
# 1                                 Very High Priority
# 2                                       Low Priority
# 3                                       Low Priority
# 4                                    Lowest Priority
#
#   preferred_committee_according_to_priority_[internals]  \
# 0                                       Low Priority
# 1                                       Mid Priority
# 2                                    Lowest Priority
# 3                                    Lowest Priority
# 4                                       Low Priority
#
#       what_are_your_other_commitments_this_semester?  \
# 0                               Thesis, Plant Design
# 1       another org, academics, personal commitments
# 2                                              acads
# 3  I am currently affiliated with UP Algo++ as pa...
# 4            I'm a working alumnus from UPLB already
#
#             what_is_your_preferred_track?  \
# 0  DS101 (preferred for beginner members)
# 1  DS101 (preferred for beginner members)
# 2  DS101 (preferred for beginner members)
# 3  DS101 (preferred for beginner members)
# 4                                   DS102
#
#                               comments_&_suggestions assigned_associate  \
# 0                                                NaN         Daryl Lara
# 1                                                NaN         Daryl Lara
# 2                                               none         Daryl Lara
# 3                                       None so far.         Daryl Lara
# 4  Siguro screenshots po from Datacamp and Data q...         Daryl Lara
#
#   Date Accomplished
# 0        2024-01-24
# 1        2024-01-24
# 2        2024-01-24
# 3        2024-01-24
# 4        2024-01-24
#
# [5 rows x 22 columns]
