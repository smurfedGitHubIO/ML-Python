# %%
import pandas as pd
import numpy as np

# %%
dataframe = pd.read_csv('./povstat_processed.csv', names=['id', 'variable', 'year', 'province', 'value', 'adm_level','region','unit'], skiprows=[0])
dataframe.head()
# Out:
#    id                                        variable  year      province  \
# 0   0  Annual Per Capita Poverty Threshold (in Pesos)  1991  1st District
# 1   1  Annual Per Capita Poverty Threshold (in Pesos)  2006  1st District
# 2   2  Annual Per Capita Poverty Threshold (in Pesos)  2009  1st District
# 3   3  Annual Per Capita Poverty Threshold (in Pesos)  2012  1st District
# 4   4  Annual Per Capita Poverty Threshold (in Pesos)  2015  1st District
#
#        value adm_level region      unit
# 0        NaN  District    NCR  in Pesos
# 1    15,699   District    NCR  in Pesos
# 2    19,227   District    NCR  in Pesos
# 3    20,344   District    NCR  in Pesos
# 4    25,007   District    NCR  in Pesos

# %%
del dataframe['id']

# %%
dataframe.head()
# Out:
#                                          variable  year      province  \
# 0  Annual Per Capita Poverty Threshold (in Pesos)  1991  1st District
# 1  Annual Per Capita Poverty Threshold (in Pesos)  2006  1st District
# 2  Annual Per Capita Poverty Threshold (in Pesos)  2009  1st District
# 3  Annual Per Capita Poverty Threshold (in Pesos)  2012  1st District
# 4  Annual Per Capita Poverty Threshold (in Pesos)  2015  1st District
#
#        value adm_level region      unit
# 0        NaN  District    NCR  in Pesos
# 1    15,699   District    NCR  in Pesos
# 2    19,227   District    NCR  in Pesos
# 3    20,344   District    NCR  in Pesos
# 4    25,007   District    NCR  in Pesos

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3605 entries, 0 to 3604
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   variable   3605 non-null   object
#  1   year       3605 non-null   int64
#  2   province   3605 non-null   object
#  3   value      3010 non-null   object
#  4   adm_level  3360 non-null   object
#  5   region     3360 non-null   object
#  6   unit       3605 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 197.3+ KB

# %%
dataframe.describe()
# Out:
#               year
# count  3605.000000
# mean   2006.600000
# std       8.358192
# min    1991.000000
# 25%    2006.000000
# 50%    2009.000000
# 75%    2012.000000
# max    2015.000000

# %%
dataframe.shape
# Out:
# (3605, 7)

# %%
dataframe = dataframe.pivot(index=['variable'], columns=['year', 'province', 'region'], values='value')

# %%
dataframe.head()
# Out:
# year                                                   1991         2006  \
# province                                       1st District 1st District
# region                                                  NCR          NCR
# variable
# Annual Per Capita Poverty Threshold (in Pesos)          NaN      15,699
# Magnitude of Poor Families                              NaN       9,906
# Magnitude of Poor Population                            NaN      79,109
# Magnitude of Subsistence Poor Population                NaN      22,528
# Poverty Incidence among Families (%)                    NaN          2.7
#
# year                                                   2009         2012  \
# province                                       1st District 1st District
# region                                                  NCR          NCR
# variable
# Annual Per Capita Poverty Threshold (in Pesos)      19,227       20,344
# Magnitude of Poor Families                          12,405       14,343
# Magnitude of Poor Population                        84,914      102,591
# Magnitude of Subsistence Poor Population                  0       8,902
# Poverty Incidence among Families (%)                    3.2          3.6
#
# year                                                   2015         1991  \
# province                                       1st District 2nd District
# region                                                  NCR          NCR
# variable
# Annual Per Capita Poverty Threshold (in Pesos)      25,007           NaN
# Magnitude of Poor Families                          12,710           NaN
# Magnitude of Poor Population                        82,007           NaN
# Magnitude of Subsistence Poor Population            24,855           NaN
# Poverty Incidence among Families (%)                    3.5          NaN
#
# year                                                   2006         2009  \
# province                                       2nd District 2nd District
# region                                                  NCR          NCR
# variable
# Annual Per Capita Poverty Threshold (in Pesos)      15,699       19,227
# Magnitude of Poor Families                          28,247       21,168
# Magnitude of Poor Population                       183,449      131,502
# Magnitude of Subsistence Poor Population            13,020       17,896
# Poverty Incidence among Families (%)                    3.2          2.2
#
# year                                                   2012         2015  ...  \
# province                                       2nd District 2nd District  ...
# region                                                  NCR          NCR  ...
# variable                                                                  ...
# Annual Per Capita Poverty Threshold (in Pesos)      20,344       25,007   ...
# Magnitude of Poor Families                          19,782       21,727   ...
# Magnitude of Poor Population                       104,495      137,392   ...
# Magnitude of Subsistence Poor Population            16,828       15,456   ...
# Poverty Incidence among Families (%)                    1.9          1.9  ...
#
# year                                                          1991  \
# province                                       Zamboanga del Norte
# region                                                   Region IX
# variable
# Annual Per Capita Poverty Threshold (in Pesos)                 NaN
# Magnitude of Poor Families                                     NaN
# Magnitude of Poor Population                                   NaN
# Magnitude of Subsistence Poor Population                       NaN
# Poverty Incidence among Families (%)                           NaN
#
# year                                                          2006  \
# province                                       Zamboanga del Norte
# region                                                   Region IX
# variable
# Annual Per Capita Poverty Threshold (in Pesos)             13,464
# Magnitude of Poor Families                                113,288
# Magnitude of Poor Population                              597,173
# Magnitude of Subsistence Poor Population                  433,317
# Poverty Incidence among Families (%)                          60.3
#
# year                                                          2009  \
# province                                       Zamboanga del Norte
# region                                                   Region IX
# variable
# Annual Per Capita Poverty Threshold (in Pesos)             17,184
# Magnitude of Poor Families                                121,830
# Magnitude of Poor Population                              650,867
# Magnitude of Subsistence Poor Population                  440,573
# Poverty Incidence among Families (%)                          60.3
#
# year                                                          2012  \
# province                                       Zamboanga del Norte
# region                                                   Region IX
# variable
# Annual Per Capita Poverty Threshold (in Pesos)             18,483
# Magnitude of Poor Families                                104,138
# Magnitude of Poor Population                              518,347
# Magnitude of Subsistence Poor Population                  328,083
# Poverty Incidence among Families (%)                          48.0
#
# year                                                          2015  \
# province                                       Zamboanga del Norte
# region                                                   Region IX
# variable
# Annual Per Capita Poverty Threshold (in Pesos)             21,725
# Magnitude of Poor Families                                 99,149
# Magnitude of Poor Population                              588,451
# Magnitude of Subsistence Poor Population                  318,045
# Poverty Incidence among Families (%)                          41.1
#
# year                                                        1991  \
# province                                       Zamboanga del Sur
# region                                                 Region IX
# variable
# Annual Per Capita Poverty Threshold (in Pesos)               NaN
# Magnitude of Poor Families                                   NaN
# Magnitude of Poor Population                                 NaN
# Magnitude of Subsistence Poor Population                     NaN
# Poverty Incidence among Families (%)                         NaN
#
# year                                                        2006  \
# province                                       Zamboanga del Sur
# region                                                 Region IX
# variable
# Annual Per Capita Poverty Threshold (in Pesos)           11,508
# Magnitude of Poor Families                               91,993
# Magnitude of Poor Population                            515,055
# Magnitude of Subsistence Poor Population                268,576
# Poverty Incidence among Families (%)                        27.4
#
# year                                                        2009  \
# province                                       Zamboanga del Sur
# region                                                 Region IX
# variable
# Annual Per Capita Poverty Threshold (in Pesos)           14,679
# Magnitude of Poor Families                               99,107
# Magnitude of Poor Population                            532,271
# Magnitude of Subsistence Poor Population                261,992
# Poverty Incidence among Families (%)                        26.9
#
# year                                                        2012  \
# province                                       Zamboanga del Sur
# region                                                 Region IX
# variable
# Annual Per Capita Poverty Threshold (in Pesos)           17,961
# Magnitude of Poor Families                              104,133
# Magnitude of Poor Population                            587,598
# Magnitude of Subsistence Poor Population                209,765
# Poverty Incidence among Families (%)                        25.9
#
# year                                                        2015
# province                                       Zamboanga del Sur
# region                                                 Region IX
# variable
# Annual Per Capita Poverty Threshold (in Pesos)           20,095
# Magnitude of Poor Families                               79,334
# Magnitude of Poor Population                            476,765
# Magnitude of Subsistence Poor Population                143,740
# Poverty Incidence among Families (%)                        18.6
#
# [5 rows x 515 columns]

# %%
dataframe.shape
# Out:
# (7, 515)

# %%
dataframe.loc['Magnitude of Poor Families', :].loc[2006, '1st District', 'NCR']
# Out:
# '  9,906 '

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Annual Per Capita Poverty Threshold (in Pesos) to Subsistence Incidence among Population (%)
# Columns: 515 entries, (1991, '1st District', 'NCR') to (2015, 'Zamboanga del Sur', 'Region IX')
# dtypes: object(515)
# memory usage: 28.5+ KB
